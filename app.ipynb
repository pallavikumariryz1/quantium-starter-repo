# %%
import pandas as pd
# !pip install dash
# Out:
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\anaconda3\lib\site-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\anaconda3\lib\site-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\anaconda3\lib\site-packages (from dash) (6.3.0)
# Requirement already satisfied: importlib-metadata in c:\anaconda3\lib\site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\anaconda3\lib\site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in c:\anaconda3\lib\site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from dash) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (2.7.0)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->dash) (2025.11.12)

# %%
import dash
from dash import dcc, html,Dash,Input,Output
import plotly.express as px

# %%
# Load data
df = pd.read_csv("output.csv")

df.head()
# Out:
#     sales        date region
# 0  1638.0  2018-02-06  north
# 1  1647.0  2018-02-06  south
# 2  1731.0  2018-02-06   east
# 3  1557.0  2018-02-06   west
# 4  1587.0  2018-02-07  north

# %%
# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])

# Sort by date
df = df.sort_values(by="date")

## Create line chart
fig = px.line(
    df,
    x = "date",
    y = "sales",
    title = "Sales of Pink Morsels over time",
    labels={"date":"Date","sales":"Sales"}
)

# Create Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1(
        "Pink Morsels Sales Visualizer",
    ),# header
    dcc.Graph(
        id="sales-chart",
        figure=fig
    )   

])

# Run app
if __name__ == "__main__":
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Create Dash app
app = dash.Dash(__name__)

# Layout
app.layout = html.Div(
    style={"backgroundColor": "#f5f5f5", "padding": "20px"},
    children=[

        html.H1(
            "Pink Morsel Sales Dashboard",
            id = "header",
            style={"textAlign": "center", "color": "#2c3e50"}
        ),

        # Radio buttons
        dcc.RadioItems(
            id="region-filter",
            options=[
                {"label": "All", "value": "all"},
                {"label": "North", "value": "north"},
                {"label": "South", "value": "south"},
                {"label": "East", "value": "east"},
                {"label": "West", "value": "west"},
            ],
            value="all",
            inline=True,
            style={"textAlign": "center", "marginBottom": "20px"}
        ),

        # Graph
        dcc.Graph(id="sales-chart")
    ]
)

# Callback (dynamic update)
@app.callback(
    Output("sales-chart", "figure"),
    Input("region-filter", "value")
)
def update_chart(selected_region):

    if selected_region == "all":
        filtered_df = df
    else:
        filtered_df = df[df["region"].str.lower() == selected_region]

    filtered_df = filtered_df.sort_values(by="date")

    fig = px.line(
        filtered_df,
        x="date",
        y="sales",
        title="Sales Over Time",
        labels={"date": "Date", "sales": "Sales"}
    )

    # Add vertical line (bonus 🔥)
    fig.add_vline(
        x="2021-01-15",
        line_dash="dash",
        line_color="red"
    )

    return fig

# Run app
if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 67
#      65 # Run app
#      66 if __name__ == "__main__":
# ---> 67     app.run(debug=True)
#
# File C:\anaconda3\Lib\site-packages\dash\dash.py:2519, in Dash.run(self, host, port, proxy, debug, hide_all_callbacks, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2516             extra_files.append(path)
#    2518 if jupyter_dash.active:
# -> 2519     jupyter_dash.run_app(
#    2520         self,
#    2521         mode=jupyter_mode,
#    2522         width=jupyter_width,
#    2523         height=jupyter_height,
#    2524         host=host,
#    2525         port=port,
#    2526         server_url=jupyter_server_url,
#    2527     )
#    2528 else:
#    2529     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File C:\anaconda3\Lib\site-packages\dash\_jupyter.py:474, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     472     display(HTML(msg))
#     473 else:
# --> 474     raise final_error
#
# File C:\anaconda3\Lib\site-packages\dash\_jupyter.py:461, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     458         raise err
#     460 try:
# --> 461     wait_for_app()
#     463     if self.in_colab:
#     464         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File C:\anaconda3\Lib\site-packages\retrying.py:55, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      53 @wraps(f)
#      54 def wrapped_f(*args, **kw):
# ---> 55     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File C:\anaconda3\Lib\site-packages\retrying.py:289, in Retrying.call(self, fn, *args, **kwargs)
#     286 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     287     if not self._wrap_exception and attempt.has_exception:
#     288         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 289         raise attempt.get()
#     290     else:
#     291         raise RetryError(attempt)
#
# File C:\anaconda3\Lib\site-packages\retrying.py:326, in Attempt.get(self, wrap_exception)
#     324     else:
#     325         exc_type, exc, tb = self.value
# --> 326         raise exc.with_traceback(tb)
#     327 else:
#     328     return self.value
#
# File C:\anaconda3\Lib\site-packages\retrying.py:273, in Retrying.call(self, fn, *args, **kwargs)
#     270     self._before_attempts(attempt_number)
#     272 try:
# --> 273     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     274 except Exception:
#     275     tb = sys.exc_info()
#
# File C:\anaconda3\Lib\site-packages\dash\_jupyter.py:452, in JupyterDash.run_app.<locals>.wait_for_app()
#     450     if res != "Alive":
#     451         url = f"http://{host}:{port}"
# --> 452         raise OSError(
#     453             f"Address '{url}' already in use.\n"
#     454             "    Try passing a different port to run."
#     455         )
#     456 except requests.ConnectionError as err:
#     457     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run.
