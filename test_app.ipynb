# %%
# Installing required packages
#!pip install multiprocess
# !pip install "dash[testing]"
# Out:
# Requirement already satisfied: dash[testing] in c:\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\anaconda3\lib\site-packages (from dash[testing]) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\anaconda3\lib\site-packages (from dash[testing]) (3.1.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\anaconda3\lib\site-packages (from dash[testing]) (6.6.0)
# Requirement already satisfied: importlib-metadata in c:\anaconda3\lib\site-packages (from dash[testing]) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\anaconda3\lib\site-packages (from dash[testing]) (4.15.0)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from dash[testing]) (2.32.5)
# Requirement already satisfied: retrying in c:\anaconda3\lib\site-packages (from dash[testing]) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\anaconda3\lib\site-packages (from dash[testing]) (1.6.0)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from dash[testing]) (80.9.0)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in c:\anaconda3\lib\site-packages (from dash[testing]) (4.14.3)
# Requirement already satisfied: cryptography in c:\anaconda3\lib\site-packages (from dash[testing]) (46.0.5)
# Requirement already satisfied: lxml>=4.6.2 in c:\anaconda3\lib\site-packages (from dash[testing]) (5.3.0)
# Collecting percy>=2.0.2 (from dash[testing])
#   Using cached percy-2.0.2-py2.py3-none-any.whl.metadata (821 bytes)
# Requirement already satisfied: pytest>=6.0.2 in c:\anaconda3\lib\site-packages (from dash[testing]) (9.0.2)
# Collecting selenium<=4.2.0,>=3.141.0 (from dash[testing])
#   Using cached selenium-4.2.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: waitress>=1.4.4 in c:\anaconda3\lib\site-packages (from dash[testing]) (3.0.2)
# Requirement already satisfied: multiprocess>=0.70.12 in c:\anaconda3\lib\site-packages (from dash[testing]) (0.70.19)
# Requirement already satisfied: psutil>=5.8.0 in c:\anaconda3\lib\site-packages (from dash[testing]) (7.0.0)
# Collecting dash_testing_stub>=0.0.2 (from dash[testing])
#   Using cached dash_testing_stub-0.0.2-py3-none-any.whl.metadata (587 bytes)
# Requirement already satisfied: blinker>=1.9.0 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash[testing]) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash[testing]) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash[testing]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash[testing]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash[testing]) (3.0.2)
# Collecting urllib3~=1.26 (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: trio~=0.17 in c:\anaconda3\lib\site-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]) (0.32.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\anaconda3\lib\site-packages (from selenium<=4.2.0,>=3.141.0->dash[testing]) (0.12.2)
# Requirement already satisfied: attrs>=23.2.0 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (2.4.0)
# Requirement already satisfied: idna in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (3.11)
# Requirement already satisfied: outcome in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (1.3.0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda3\lib\site-packages (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]) (1.3.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]) (26.0.0)
# Requirement already satisfied: certifi in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]) (2026.1.4)
# Collecting urllib3-secure-extra (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing])
#   Using cached urllib3_secure_extra-0.1.0-py2.py3-none-any.whl.metadata (828 bytes)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium<=4.2.0,>=3.141.0->dash[testing]) (1.7.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.2->dash[testing]) (2.5)
# Requirement already satisfied: pycparser in c:\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]) (2.23)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash[testing]) (0.4.6)
# Requirement already satisfied: dill>=0.4.1 in c:\anaconda3\lib\site-packages (from multiprocess>=0.70.12->dash[testing]) (0.4.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash[testing]) (2.7.0)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from plotly>=5.0.0->dash[testing]) (25.0)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\anaconda3\lib\site-packages (from pytest>=6.0.2->dash[testing]) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\anaconda3\lib\site-packages (from pytest>=6.0.2->dash[testing]) (1.5.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\anaconda3\lib\site-packages (from pytest>=6.0.2->dash[testing]) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->dash[testing]) (3.4.4)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\anaconda3\lib\site-packages (from importlib-metadata->dash[testing]) (3.23.0)
# Using cached selenium-4.2.0-py3-none-any.whl (983 kB)
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Using cached dash_testing_stub-0.0.2-py3-none-any.whl (2.6 kB)
# Using cached percy-2.0.2-py2.py3-none-any.whl (12 kB)
# Using cached urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Installing collected packages: urllib3-secure-extra, dash_testing_stub, urllib3, percy, selenium
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.6.3
#
#     Uninstalling urllib3-2.6.3:
#
#       Successfully uninstalled urllib3-2.6.3
#
#    ---------------- ----------------------- 2/5 [urllib3]
#    ---------------- ----------------------- 2/5 [urllib3]
#    ---------------- ----------------------- 2/5 [urllib3]
#    ---------------- ----------------------- 2/5 [urllib3]
#    ---------------- ----------------------- 2/5 [urllib3]
#    ------------------------ --------------- 3/5 [percy]
#   Attempting uninstall: selenium
#    ------------------------ --------------- 3/5 [percy]
#    -------------------------------- ------- 4/5 [selenium]
#     Found existing installation: selenium 4.41.0
#    -------------------------------- ------- 4/5 [selenium]
#     Uninstalling selenium-4.41.0:
#    -------------------------------- ------- 4/5 [selenium]
#       Successfully uninstalled selenium-4.41.0
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    -------------------------------- ------- 4/5 [selenium]
#    ---------------------------------------- 5/5 [selenium]
#
# Successfully installed dash_testing_stub-0.0.2 percy-2.0.2 selenium-4.2.0 urllib3-1.26.20 urllib3-secure-extra-0.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.173 requires urllib3>=2.2.2, but you have urllib3 1.26.20 which is incompatible.

# %%
import pytest
from dash.testing.application_runners import import_app

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\anaconda3\lib\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in c:\anaconda3\lib\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->webdriver-manager) (2026.1.4)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Load app
@pytest.fixture
def app():
    return import_app("app") # filename without any version 

# overriding pytest fixture
@pytest.fixture
def dash_duo(dash_duo):
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)
    dash_duo.driver = driver
    return dash_duo
    
# Test 1: Header exists or not
def test_header(dash_duo,app):
    dash_duo.start_server(app)
    header = dash_duo.find_element("#header")
    assert header is not None

# Test 2: Graph exists or not
def test_graph(dash_duo,app):
    dash_duo.start_server(app)
    graph = dash_duo.find_element("#sales-chart")
    assert graph is not None

# Test 3: Radio button exists or not
def test_radio_button(dash_duo,app):
    dash_duo.start_server(app)
    radio_button = dash_duo.find_element("#region-filter")
    assert radio_button is not None
